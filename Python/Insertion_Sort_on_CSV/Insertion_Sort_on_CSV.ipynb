# %%
import pandas as pd
def sort_col(file='dataset.csv',cols=0,rows=0):
    df = pd.read_csv(file,delimiter=',')
    readList = [list(x) for x in df.values]
    
    res = []
    for i in range(len(readList)):
       #loop through the original list
       if len(res) == 0:
          # if we don't have any items in our result list, we add first element here.
          res.append(readList[i])
       else:
          done = False
          for j in range(len(res)):
              #loop through the result list this far
              if res[j][cols] > readList[i][cols]:
                  #if our item in list is smaller than element in res list, we insert it here
                  res.insert(j, readList[i])
                  done = True
                  break
          if not done:
             #if our item in list is bigger than all the items in result list, we put it last.
             res.append(readList[i])
    ress = list(list(zip(*res))[cols])
    return ress

# %%
sort_col('dataset.csv',2,189)
# Out:
# [30,
#  50,
#  50,
#  50,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  150,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  250,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  350,
#  350,
#  350,
#  400,
#  400,
#  400,
#  450,
#  450,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  500,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  700,
#  700,
#  700,
#  750,
#  800,
#  900,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1100,
#  1100,
#  1100,
#  1300,
#  1400,
#  1500,
#  1500,
#  1500,
#  1600,
#  1700,
#  1700,
#  1700,
#  1800,
#  1900,
#  2000,
#  2000,
#  2100,
#  2300,
#  2300,
#  2300,
#  2300,
#  2400,
#  2400,
#  2500,
#  2500,
#  2500,
#  2500,
#  2600,
#  2600,
#  3000,
#  3000,
#  3300,
#  3400,
#  3500,
#  3500,
#  3500,
#  3800,
#  4000,
#  4000,
#  4000,
#  4000,
#  4100,
#  4300,
#  4500,
#  5000,
#  6300,
#  7000,
#  7000,
#  7000,
#  7000,
#  8000,
#  8000,
#  8250,
#  8300,
#  9000,
#  9000,
#  9100,
#  10000,
#  10000,
#  10050,
#  15000,
#  16000,
#  19300,
#  22000,
#  25000,
#  26000,
#  28300,
#  29000,
#  30000,
#  30000,
#  31000,
#  40000,
#  40000,
#  50000,
#  80000,
#  80000,
#  115000,
#  360000,
#  500000]
